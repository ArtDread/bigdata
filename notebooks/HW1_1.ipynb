# %% [markdown]
# # Homework 1, part 1

# %%
# !hadoop fs -ls /
# Out:
# Found 2 items
# drwx-wx-wx   - root supergroup          0 2023-11-28 21:21 /tmp
# drwxr-xr-x   - root supergroup          0 2023-11-28 21:21 /user

# %%
# !hadoop fs -mkdir /book

# %%
# !hadoop fs -ls /
# Out:
# Found 3 items
# drwxr-xr-x   - root supergroup          0 2023-11-28 21:33 /book
# drwx-wx-wx   - root supergroup          0 2023-11-28 21:21 /tmp
# drwxr-xr-x   - root supergroup          0 2023-11-28 21:21 /user

# %%
# !ls ../data
# Out:
# PrinciplesOfLazersZvelto.pdf  rubrics.json

# %%
# !hadoop fs -put ../data/PrinciplesOfLazersZvelto.pdf /book && hadoop fs -put ../data/rubrics.json /book

# %%
# !hadoop fs -ls /book/PrinciplesOfLazersZvelto.pdf
# Out:
# -rw-r--r--   3 root supergroup   32359249 2023-11-28 21:33 /book/PrinciplesOfLazersZvelto.pdf

# %%
# !hadoop fs -ls /book/rubrics.json
# Out:
# -rw-r--r--   3 root supergroup     423695 2023-11-28 21:33 /book/rubrics.json

# %%
# !hadoop fs -cat /book/rubrics.json
# Out:
# {
#     "1": {
#         "isRussian": true,
#         "isNonRussian": true,
#         "label": "Город / Власть",
#         "code": "1",
#         "parentCode": "0",
#         "children": [
#             "16",
#             "1192",
#             "17",
#             "115",
#             "44",
#             "45",
#             "54850",
#             "20",
#             "19",
#             "21",
#             "24773",
#             "40"
#         ]
#     },
#     "2": {
#         "isRussian": true,
#         "isNonRussian": true,
#         "label": "Досуг / Развлечения / Общественное питание",
#         "code": "2",
#         "parentCode": "0",
#         "children": [
#             "26",
#             "25",
#             "22215",
#             "13786"
#         ]
#     },
#     "3": {
#         "isRussian": true,
#         "isNonRussian": true,
#         "label": "Компьютеры / Бытовая техника / Офисная техника",
#         "code": "3",
#         "parentCode": "0",
#         "children": [
# ...

# %%
# !hadoop jar /opt/hadoop/share/hadoop/mapreduce/hadoop-mapreduce-examples-3.3.6.jar pi 15 1800
# Out:
# Number of Maps  = 15
# Samples per Map = 1800
# Wrote input for Map #0
# Wrote input for Map #1
# Wrote input for Map #2
# Wrote input for Map #3
# Wrote input for Map #4
# Wrote input for Map #5
# Wrote input for Map #6
# Wrote input for Map #7
# Wrote input for Map #8
# Wrote input for Map #9
# Wrote input for Map #10
# Wrote input for Map #11
# Wrote input for Map #12
# Wrote input for Map #13
# Wrote input for Map #14
# Starting Job
# 2023-11-28 21:21:19 INFO  DefaultNoHARMFailoverProxyProvider:64 - Connecting to ResourceManager at resourcemanager/172.21.0.6:8032
# 2023-11-28 21:21:19 INFO  JobResourceUploader:907 - Disabling Erasure Coding for path: /tmp/hadoop-yarn/staging/root/.staging/job_1701195374415_0001
# 2023-11-28 21:21:20 INFO  FileInputFormat:300 - Total input files to process : 15
# 2023-11-28 21:21:20 INFO  JobSubmitter:202 - number of splits:15
# 2023-11-28 21:21:20 INFO  JobSubmitter:298 - Submitting tokens for job: job_1701195374415_0001
# ...
